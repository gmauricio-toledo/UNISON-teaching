# %% [markdown]
# <a href="https://colab.research.google.com/github/gmauricio-toledo/numerical-methods/blob/master/Examen-reposicion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git init
# !git pull https://github.com/gmauricio-toledo/numerical-methods.git
# Out:
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 236, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 236 (delta 23), reused 31 (delta 10), pack-reused 182
# Receiving objects: 100% (236/236), 2.61 MiB | 14.38 MiB/s, done.
# Resolving deltas: 100% (121/121), done.
# From https://github.com/gmauricio-toledo/numerical-methods
#  * branch            HEAD       -> FETCH_HEAD

# %%
from interpolacion_aproximacion import RegresionLineal
import numpy as np

# %%
X = np.array([[26.67,1.35],[93.33,0.085],[148.89,0.012],[315.56,0.00075]])

print(X)
# Out:
# [[2.6670e+01 1.3500e+00]
#  [9.3330e+01 8.5000e-02]
#  [1.4889e+02 1.2000e-02]
#  [3.1556e+02 7.5000e-04]]

# %%
rl = RegresionLineal(grado=1)

rl.fit(X)
rl.plot()
rl.metrics()
# Out:
# Error respecto al promedio: 1.3058745468750002
# Error cuadrático: 0.706945691144693
# S_r<S_t : True
# Desviación estandar de los datos y_i: 0.6597662583256286
# Error estandar de la estimación: 0.594535823624066
# S_r<S_t : True
# Coeficiente de determinación: 0.4586419554340524

# %%
rl = RegresionLineal(grado=2)

rl.fit(X)
rl.plot()
rl.metrics()
# Out:
# Error respecto al promedio: 1.3058745468750002
# Error cuadrático: 0.09451953988962768
# S_r<S_t : True
# Desviación estandar de los datos y_i: 0.6597662583256286
# Error estandar de la estimación: 0.3074403029689303
# S_r<S_t : True
# Coeficiente de determinación: 0.9276197394950257

# %%
X_log = X.copy()

X_log[:,1] = np.log(X[:,1])

print(X_log)
print(X)

rl = RegresionLineal(grado=1)

rl.fit(X_log)
rl.plot()
rl.metrics()
# Out:
# [[ 2.66700000e+01  3.00104592e-01]
#  [ 9.33300000e+01 -2.46510402e+00]
#  [ 1.48890000e+02 -4.42284863e+00]
#  [ 3.15560000e+02 -7.19543735e+00]]
# [[2.6670e+01 1.3500e+00]
#  [9.3330e+01 8.5000e-02]
#  [1.4889e+02 1.2000e-02]
#  [3.1556e+02 7.5000e-04]]
# Error respecto al promedio: 30.007970105296017
# Error cuadrático: 1.7515928763925321
# S_r<S_t : True
# Desviación estandar de los datos y_i: 3.1626976937047493
# Error estandar de la estimación: 0.9358399639875752
# S_r<S_t : True
# Coeficiente de determinación: 0.9416290782000146
