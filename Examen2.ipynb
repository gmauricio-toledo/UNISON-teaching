# %% [markdown]
# <a href="https://colab.research.google.com/github/gmauricio-toledo/numerical-methods/blob/master/Examen2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git init
# !git pull https://github.com/gmauricio-toledo/numerical-methods.git
# Out:
# Initialized empty Git repository in /content/.git/
# remote: Enumerating objects: 152, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (130/130), done.
# remote: Total 152 (delta 75), reused 66 (delta 20), pack-reused 0
# Receiving objects: 100% (152/152), 1.50 MiB | 1.80 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# From https://github.com/gmauricio-toledo/numerical-methods
#  * branch            HEAD       -> FETCH_HEAD

# %% [markdown]
# # Ejercicios examen

# %%
from numpy.random.mtrand import seed
import numpy as np
import matplotlib.pyplot as plt

f = lambda x: -(x**3)/6 + 7

np.random.seed(47)
xs = np.linspace(-3,3,num=6)
noise = np.random.normal(0,1.25,size=xs.shape)
ys = f(xs)+noise
datos = np.transpose(np.vstack((xs,ys)))

plt.figure(dpi=100)
plt.scatter(datos[:,0],datos[:,1],color='black',s=70)
plt.xticks([x-3 for x in range(7)],fontsize=14)
plt.yticks(list(range(5,11)),fontsize=14)
plt.show()

# %%
for x,y in zip(xs,ys):
    print(f"{round(x,4)} & {round(y,4)} \\\\")
# Out:
# -3.0 & 10.44 \\
# -1.8 & 9.6044 \\
# -0.6 & 8.1913 \\
# 0.6 & 7.7645 \\
# 1.8 & 4.7096 \\
# 3.0 & 4.7472 \\

# %%
from interpolacion_aproximacion import RegresionLineal

rl = RegresionLineal(grado=1)
rl.fit(datos,report=True)
rl.metrics()
rl.plot()
print(f"{rl.a_0} + {rl.a_1}x")
# Out:
# x_prom = -1.4802973661668753e-16,
# y_prom = 7.576154246215,
# sum_xy = -26.14505642486716,
# sum_x_2s = 25.2,
# sum_x = -8.881784197001252e-16,
# sum_y = 45.45692547729
# Error respecto al promedio: 28.949323062282584
# Error cuadrático: 1.8237684805568968
# S_r<S_t : True
# Desviación estandar de los datos y_i: 2.406213750367269
# Error estandar de la estimación: 0.6752348629471261
# S_r<S_t : True
# Coeficiente de determinación: 0.9370013427729147
# 7.576154246215 + -1.03750223908203x

# %%
rp = RegresionLineal(grado=2)
rp.fit(datos)
rp.metrics()
rp.plot()
# Out:
# Error respecto al promedio: 28.949323062282584
# Error cuadrático: 1.7660909971273833
# S_r<S_t : True
# Desviación estandar de los datos y_i: 2.406213750367269
# Error estandar de la estimación: 0.767265924593593
# S_r<S_t : True
# Coeficiente de determinación: 0.9389937031229452

# %%
from integracion import Trapezoid

trap = Trapezoid(datos=datos)
trap.fit(0,1,3)
# Out:
# a,b,n will be ignored.
# 45.43599714322852

# %% [markdown]
# # Examen 2023-2 II

# %% [markdown]
# ## Ejercicio 1

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([[3,4],[5,2],[6,3],[8,1]])
print(f"Datos:\n{X}")

plt.figure()
plt.scatter(X[:,0],X[:,1],color='black',s=60)
plt.show()
# Out:
# Datos:
# [[3 4]
#  [5 2]
#  [6 3]
#  [8 1]]

# %%
from interpolacion_aproximacion import RegresionLineal

rl = RegresionLineal(grado=1)
rl.fit(X)
rl.metrics()
rl.plot()
# Out:
# Pendiente: -0.5384615384615384, Intercepto: 5.461538461538462
# Error respecto al promedio: 5.0
# Error cuadrático: 1.2307692307692313
# S_r < S_t : True
# Desviación estandar de los datos y_i: 1.2909944487358056
# Error estandar de la estimación (s_yx): 0.7844645405527363
# S_yx < S_y : True
# Coeficiente de determinación r2: 0.7538461538461537

# %%
rl.eval(7)
# Out:
# 1.6923076923076925

# %% [markdown]
# ## Ejercicio 2

# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([[1,4],[2,1],[4,7],[5,14]])
print(f"Datos:\n{X}")

plt.figure()
plt.scatter(X[:,0],X[:,1],color='black',s=60)
plt.show()
# Out:
# Datos:
# [[ 1  4]
#  [ 2  1]
#  [ 4  7]
#  [ 5 14]]

# %%
from interpolacion_aproximacion import InterpolacionLagrange

il = InterpolacionLagrange()
il.fit(X,2)
il.plot()

# %%
il.eval(3)
# Out:
# 1.9999999999999998
