# %% [markdown]
# Funciones

# %%
from numpy import e
import matplotlib.pyplot as plt
import numpy as np

def f(x):
    return e**(-x)+x-2

# def f(x):
#     return x**10 - 1

# %% [markdown]
# Graficamos la función. Usamos [numpy.linspace](https://numpy.org/doc/stable/reference/generated/numpy.linspace.html) para generar los puntos sobre el eje X.

# %%
eje_x = np.linspace(start=-2.5,
                    stop=2.5,
                    num=100)

# eje_y = [f(x) for x in eje_x]  # Listas de compresión 

eje_y = []
for x in eje_x:
    eje_y.append(f(x))

plt.figure(figsize=(7,5))
plt.plot(eje_x,eje_y,color='red')
plt.axhline(0,color='gray') # Dibujar eje X
plt.axvline(0,color='gray') # Dibujar eje Y
plt.show()

# %% [markdown]
# # Método bisección

# %%
from roots import RootFinder

rf = RootFinder()
raiz = rf.fit(f=f,tolerance=0.001,
              x0=0,x1=2,
              method='bisection')
# raiz = rf.fit(f=f,tolerance=0.001,x0=0,x1=1.5,method='bisection')
rf.print_table(digits=4)
# Out:
# Possible methods: ['bisection', 'false-position', 'fix', 'newton', 'secant']
#     n_iter    root   error    f(x)
# 0        1  1.0000  1.0000 -0.6321
# 1        2  1.5000  0.3333 -0.2769
# 2        3  1.7500  0.1429 -0.0762
# 3        4  1.8750  0.0667  0.0284
# 4        5  1.8125  0.0345 -0.0243
# 5        6  1.8438  0.0169  0.0020
# 6        7  1.8281  0.0085 -0.0112
# 7        8  1.8359  0.0043 -0.0046
# 8        9  1.8398  0.0021 -0.0013
# 9       10  1.8418  0.0011  0.0003
# 10      11  1.8408  0.0005 -0.0005

# %%
rf.plot()

# %%
rf.errors
# Out:
# [1.0,
#  0.3333333333333333,
#  0.14285714285714285,
#  0.06666666666666667,
#  0.034482758620689655,
#  0.01694915254237288,
#  0.008547008547008548,
#  0.00425531914893617,
#  0.0021231422505307855,
#  0.0010604453870625664,
#  0.0005305039787798408]

# %%
plt.figure()
plt.plot(rf.errors)
plt.show()

# %% [markdown]
# # Método Bisección & Falsa Posición

# %%
from roots import RootFinder



rf = RootFinder()
raiz = rf.fit(f=f,tolerance=0.001,x0=0,x1=2,method='false-position') # Ejemplo 1
# raiz = rf.fit(f=f,tolerance=0.001,x0=0,x1=1.5,method='false-position') # Ejemplo 2: x^10-1
rf.print_table(digits=4)
# Out:
# Possible methods: ['bisection', 'false-position', 'fix', 'newton', 'secant']
#    n_iter    root   error    f(x)
# 0       1  1.7616  1.0000 -0.0666
# 1       2  1.8403  0.0427 -0.0010
# 2       3  1.8414  0.0006 -0.0000

# %%
plt.figure()
plt.plot(list(range(len(rf.errors))),rf.errors)
plt.xticks(list(range(len(rf.errors))))
plt.show()

# %% [markdown]
# # Método de Newton

# %%
from roots import RootFinder

def df(x):
    return -e**(-x)+1

rf = RootFinder()
raiz = rf.fit(f=f,tolerance=0.001,x0=4,df=df,method='newton') # Ejemplo 1
rf.print_table()
# Out:
# Possible methods: ['bisection', 'false-position', 'fix', 'newton', 'secant']
#    n_iter     root    error     f(x)
# 0       1  1.94403  1.05758  0.08715
# 1       2  1.84232  0.05521  0.00077
# 2       3  1.84141  0.00049  0.00000

# %%
plt.figure()
plt.plot(list(range(len(rf.errors))),rf.errors)
plt.xticks(list(range(len(rf.errors))))
plt.show()

# %%
rf.animate(fname='ex1-newton.gif')

# %%
from roots import RootFinder
from numpy import e

x_0 = 1
x_1 = 3
tolerancia = 0.0005

def f(x):
    return 3-e**(-x)-x

def df(x):
    return -1+e**(-x)

rf = RootFinder()
rf.fit(f=f,x0=x_0,x1=x_1,tolerance=tolerancia,method='secant',df=df)
rf.print_table(digits=7)
# Out:
# Possible methods: ['bisection', 'false-position', 'fix', 'newton', 'secant']
#    n_iter      root     error      f(x)
# 0       1  2.940797  0.659956  0.006379
# 1       2  2.947521  0.002281  0.000009
# 2       3  2.947531  0.000003 -0.000000

# %% [markdown]
# # Método de la secante

# %%
from roots import RootFinder
from math import cos

def f(x):
    return cos(x/2)

rf = RootFinder()
rf.fit(f=f,x0=1,x1=1.5,tolerance=0.001,method='secant')
rf.print_table(digits=7)
# Out:
# Possible methods: ['bisection', 'false-position', 'fix', 'newton', 'secant']
#    n_iter      root     error          f(x)
# 0       1  4.007610  0.750475 -4.196035e-01
# 1       2  3.093679  0.295419  2.395470e-02
# 2       3  3.143036  0.015704 -7.218000e-04
# 3       4  3.141592  0.000460  1.000000e-07

# %% [markdown]
# # Punto fijo

# %%
from math import e
import numpy as np
import matplotlib.pyplot as plt

def f(x):
    return e**(-x)-x

# %%
eje_x = np.linspace(start=-2.5,
                    stop=2.5,
                    num=100)

# eje_y = [f(x) for x in eje_x]  # Listas de compresión 

eje_y = []
for x in eje_x:
    eje_y.append(f(x))

plt.figure(figsize=(7,5))
plt.plot(eje_x,eje_y,color='red')
plt.axhline(0,color='gray') # Dibujar eje X
plt.axvline(0,color='gray') # Dibujar eje Y
plt.show()

# %%
eje_x = np.linspace(start=-2.5,
                    stop=2.5,
                    num=100)

eje_y = [f(x)+x for x in eje_x]  # Listas de compresión 

plt.figure(figsize=(7,5),dpi=150)
plt.suptitle("Iteración de punto fijo")
plt.plot(eje_x,eje_y,color='red')
plt.plot(eje_x,eje_x,color='black')
plt.axhline(0,color='gray') # Dibujar eje X
plt.axvline(0,color='gray') # Dibujar eje Y
plt.show()

# %%
from roots import RootFinder

rf = RootFinder()
rf.fit(f=f,x0=0,tolerance=0.001,method='fix')
rf.print_table(digits=7)
# Out:
# Possible methods: ['bisection', 'false-position', 'fix', 'newton', 'secant']
#     n_iter      root     error      f(x)
# 0        1  1.000000  1.000000 -0.632121
# 1        2  0.367879  1.718282  0.324321
# 2        3  0.692201  0.468536 -0.191727
# 3        4  0.500474  0.383091  0.105770
# 4        5  0.606244  0.174468 -0.060848
# 5        6  0.545396  0.111566  0.034216
# 6        7  0.579612  0.059034 -0.019497
# 7        8  0.560115  0.034809  0.011028
# 8        9  0.571143  0.019308 -0.006264
# 9       10  0.564879  0.011089  0.003549
# 10      11  0.568429  0.006244 -0.002014
# 11      12  0.566415  0.003556  0.001142
# 12      13  0.567557  0.002012 -0.000648
# 13      14  0.566909  0.001143  0.000367
# 14      15  0.567276  0.000647 -0.000208

# %%
rf.animate(fname='ex3-fix.gif')

# %% [markdown]
# El siguiente ejemplo siempre diverge con el método del punto fijo. **Cortar la ejecución en algún momento, de otra forma se queda ejecutándose indefinidamente**

# %%
def f2(x):
    return x**3-x-1

rf = RootFinder()
rf.fit(f=f2,x0=-3,tolerance=0.001,method='fix')
rf.print_table(digits=7)

# %% [markdown]
# # Comparación

# %%
x_0 = 0
x_1 = 1.5
tolerancia = 0.00001

def f(x):
    return x**10 - 1

rf_bs = RootFinder()
root_bs = rf_bs.fit(f,x0=x_0,x1=x_1,tolerance=tolerancia,method='bisection')
errors_bs = rf_bs.errors

print("-------- Método Bisección --------")
print(f"Iteraciones: {rf_bs.n_iterations}")
print(f"Solución aproximada: {root_bs}")
print(f"Error relativo aproximado: {errors_bs[-1]}")
print(f"Evaluación: {f(root_bs)}")

rf_fp = RootFinder()
root_fp = rf_fp.fit(f,x0=x_0,x1=x_1,tolerance=tolerancia,method='false-position')
errors_fp = rf_fp.errors

print("-------- Método Falsa Posición --------")
print(f"Iteraciones: {rf_fp.n_iterations}")
print(f"Solución aproximada: {root_fp}")
print(f"Error relativo aproximado: {errors_fp[-1]}")
print(f"Evaluación: {f(root_fp)}")

root_real = 1

plot_comparison(rf1=rf_bs,
                rf2=rf_fp,
                root_real=root_real,
                id="ejemplo-potencia-10")
# Out:
# -------- Método Bisección --------
# Iteraciones: 18
# Solución aproximada: 1.0000019073486328
# Error relativo aproximado: 5.722034984521895e-06
# Evaluación: 1.9073650038059498e-05
# -------- Método Bisección --------
# Iteraciones: 133
# Solución aproximada: 0.9998971708232889
# Error relativo aproximado: 9.949253374848845e-06
# Evaluación: -0.0010278160747823062

# %% [markdown]
# # Los métodos ya implementados

# %%
from scipy import optimize

sol = optimize.root_scalar(f, bracket=[0, 3], method='bisect',rtol=0.001)

# %%
sol
# Out:
#       converged: True
#            flag: 'converged'
#  function_calls: 13
#      iterations: 11
#            root: 1.84130859375

# %%
sol.root
# Out:
# 1.84130859375

# %% [markdown]
# # Generar animaciones

# %%
import itertools
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
from math import fabs

data_x = itertools.cycle(rf.roots)
data_y = itertools.cycle(np.zeros_like(rf.roots))
frames = len(rf.roots)

window_width = fabs(rf.x1-rf.x0)

eje_x = np.linspace(start=rf.x0-0.1*window_width,
                    stop=rf.x1+0.1*window_width,
                    num=100)
eje_y = [f(x) for x in eje_x] 

fig, ax = plt.subplots(figsize=(7,5))

def update(i):
    ax.clear()
    fig.suptitle(f"Iteración {i}")
    ax.axhline(0,color='gray')
    ax.plot(eje_x,eje_y,color='red')
    ax.scatter([next(data_x)], [next(data_y)],s=50,color='black')


ani = animation.FuncAnimation(fig, update, frames=frames, interval=500)
ani.save('ex1-newton.gif', writer='pillow')

# %%
from roots import RootFinder

rf = RootFinder()
# raiz = rf.fit(f=f,tolerance=0.001,x0=0,x1=2,method='false-position') # Ejemplo 1
raiz = rf.fit(f=f,tolerance=0.001,x0=0,x1=1.5,method='secant') # Ejemplo 2: x^10-1
rf.print_table(digits=4)
rf.animate(fname='ex2-secant.gif')
# Out:
# Possible methods: ['bisection', 'false-position', 'fix', 'newton', 'secant']
#    n_iter          root         error           f(x)
# 0       1  2.600000e-02  1.000000e+00  -1.000000e+00
# 1       2  5.160000e-02  4.956000e-01  -1.000000e+00
# 2       3  1.921827e+11  1.000000e+00  6.872935e+112
# 3       4  5.150000e-02  3.728503e+12  -1.000000e+00
# 4       5  5.150000e-02  0.000000e+00  -1.000000e+00

# %% [markdown]
# # Casos problemáticos

# %%
from math import sqrt

def f(x):
    if x>=0:
        y = sqrt(x)
    else:
        y = -sqrt(-x)
    return y

def df(x):
    if x>=0:
        y = 1/(2*sqrt(x))
    else:
        y = 1/(2*sqrt(-x))
    return y

# %%
from roots import RootFinder

rf = RootFinder()
rf.fit(f=f,df=df,x0=0.25,tolerance=0.000001,method='newton')
# Out:
# Possible methods: ['bisection', 'false-position', 'fix', 'newton', 'secant']
# Iteraciones máximas alcanzadas
# 0.25

# %%
rf.roots
# Out:
# [-0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  -0.25,
#  0.25,
#  ...]
